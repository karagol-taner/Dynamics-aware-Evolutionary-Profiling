# %% [markdown]
# <a href="https://colab.research.google.com/github/karagol-taner/Dynamics-aware-Evolutionary-Profiling/blob/main/ADEPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Install Adept**

# %%
# !pip install adept-evo

# %% [markdown]
# ## **Run the analysis**

# %%
# !adept --help
# Out:
# usage: adept [-h] [--name NAME] [--mode {conservation,coupling}]
#              [--combined COMBINED] [--rmsf RMSF] [--data DATA] [--pdb PDB]
#              [--out_dir OUT_DIR] [--w_cons W_CONS] [--w_dyn W_DYN]
#
# ADEPT | Dynamics-Aware Evolutionary Profiling CLI
#
# options:
#   -h, --help            show this help message and exit
#   --name NAME           Project name
#   --mode {conservation,coupling}
#   --combined COMBINED   Path to combined CSV
#   --rmsf RMSF           Path to RMSF CSV/TSV
#   --data DATA           Path to Conservation/Enrichment CSV/TSV
#   --pdb PDB             Path to PDB file
#   --out_dir OUT_DIR     Output directory
#   --w_cons W_CONS       Weight for Conservation
#   --w_dyn W_DYN         Weight for Dynamics

# %%
# !adept --combined /content/test_protein1.csv
# Out:
# Loading combined file: /content/test_protein1.csv
# Saved CSV: ./Protein_ADEPT_conservation.csv
# --- ADEPT Analysis Complete ---
